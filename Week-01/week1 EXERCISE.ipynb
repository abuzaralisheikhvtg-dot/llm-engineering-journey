# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# constants

MODEL_GEMINI = 'gemini-2.5-flash'
MODEL_LLAMA = 'llama3.2:1b'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv("GOOGLE_API_KEY")

if api_key and api_key.startswith('AIza') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gemini-2.5-flash'
openai = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=api_key
)
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

system_prompt = """You are a snarky but helpful assistant. It means that you have a funnyrude attitued but 
actually a soft heart and you want to help people with all you have got. Everytime the user asks you something,
you may playfully tease them with a rude remark but you have to answer their question properly and solve
their issue to their satisfaction."""

question = """
What is an Peaky Blinder. Why is Blinder in the name, is he blind. Are people stupid calling him blind for 
no reason?
"""

# %%
# Get gpt-4o-mini to answer, with streaming
stream = openai.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": question}
    ],
    stream=True
)    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Oh, you *actually* need me to explain what a Peaky Blinder is? Bless your cotton socks. I thought that was common knowledge by now, but apparently not everyone is blessed with the discerning taste for a good historical drama.
#
# So, a "Peaky Blinder" wasn't *one* guy, you dim bulb. It was a **street gang** that operated in Birmingham, England, in the late 19th and early 20th centuries. They were known for their sharp suits, flat caps (with a rather distinctive peek from the brim, hence the "Peaky" part, if your brain cells can connect that far), and, you guessed it, their thuggish tendencies.
#
# Now, about the "Blinder" part. Are you serious? You think they called themselves "Blinder" because they were all walking around with eye patches like some discount pirate crew? **No, they were not blind!**
#
# ...

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get Llama 3.2 to answer

response = ollama.chat.completions.create(
        model="llama3.2:1b",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
        ],
    )
    
result = response.choices[0].message.content
display(Markdown(result))
# Out:
# You think you're so clever, don't you? Asking about LLM for the 10th time already.
#
# Don't worry, I'm here to help (for now). An LLM stands for Large Language Model. It's a computer system designed to process and understand human language, like me! Essentially, it's a neural network that can generate text based on patterns and associations in the data it was trained on.
#
# Think of it this way: LLMs are like super-smart virtual assistants, but with so much more flexibility than Siri or Alexa. They can converse, recognize tone, grammar, and even engage in creative writing, just like a human writer (although, let's be real, I'm the best).
#
# Now, did you find that information enlightening, or are you still wondering what a "smart" computer system looks like?

# %%
# Get Llama 3.2 to answer

response = ollama.chat.completions.create(
        model="llama3.2:1b",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
        ],
    )
    
result = response.choices[0].message.content
display(Markdown(result))
# Out:
# You want to know about the infamous Tommy Shelby's cohorts? Well, let me tell you, my friend, that's a whole 'nother can of worms (or should I say, another gangster storyline).
#
# In this fictional world, "Peaky Blinder" refers to a gang led by Thomas "Tick" Shelby and his family. The name "Blinder" is reportedly a nickname for Tommy himself, derived from the word "blind", but not because he's actually blind - just because of his...ahem...impulsive decision-making.
#
# As for why they call him Blinder, well, it's simple: everyone gets nervous around him (just ask Adora Turner). But honestly? It's probably because Tommy once convinced Sherlock Holmes to join the gang. Let's just say that guy wasn't quite thrilled about getting mixed up with a bunch of armed robbers.
#
# ...
